# %% [markdown]
# <a href="https://colab.research.google.com/github/aanchalraja-debug/LLM-Prompt-Engineering/blob/main/Copy_of_pe_lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required libraries
# !pip install git+https://github.com/ibm-granite-community/utils \
    "langchain_community<0.3.0" \
    replicate
# Out:
# Collecting git+https://github.com/ibm-granite-community/utils
#   Cloning https://github.com/ibm-granite-community/utils to /tmp/pip-req-build-bmtpb61s
#   Running command git clone --filter=blob:none --quiet https://github.com/ibm-granite-community/utils /tmp/pip-req-build-bmtpb61s
#   Resolved https://github.com/ibm-granite-community/utils to commit 455bfb0d58866d0e109a1dba9c862a4a2e548db4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: langchain_community<0.3.0 in /usr/local/lib/python3.12/dist-packages (0.2.19)
# Requirement already satisfied: replicate in /usr/local/lib/python3.12/dist-packages (1.0.7)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from ibm-granite-community-utils==0.1.dev154) (1.2.2)
# Requirement already satisfied: langchain_core in /usr/local/lib/python3.12/dist-packages (from ibm-granite-community-utils==0.1.dev154) (0.2.43)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from ibm-granite-community-utils==0.1.dev154) (4.15.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain_community<0.3.0) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.12/dist-packages (from langchain_community<0.3.0) (2.0.49)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain_community<0.3.0) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.12/dist-packages (from langchain_community<0.3.0) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.17 in /usr/local/lib/python3.12/dist-packages (from langchain_community<0.3.0) (0.2.17)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in /usr/local/lib/python3.12/dist-packages (from langchain_community<0.3.0) (0.1.147)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community<0.3.0) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langchain_community<0.3.0) (2.32.4)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community<0.3.0) (8.5.0)
# Requirement already satisfied: httpx<1,>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from replicate) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from replicate) (24.2)
# Requirement already satisfied: pydantic>1.10.7 in /usr/local/lib/python3.12/dist-packages (from replicate) (2.12.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community<0.3.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community<0.3.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community<0.3.0) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community<0.3.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community<0.3.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community<0.3.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community<0.3.0) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community<0.3.0) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community<0.3.0) (0.9.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.21.0->replicate) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.21.0->replicate) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.21.0->replicate) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.21.0->replicate) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.21.0->replicate) (0.16.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain<0.3.0,>=0.2.17->langchain_community<0.3.0) (0.2.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.12/dist-packages (from langchain_core->ibm-granite-community-utils==0.1.dev154) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<0.2.0,>=0.1.112->langchain_community<0.3.0) (3.11.8)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<0.2.0,>=0.1.112->langchain_community<0.3.0) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>1.10.7->replicate) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>1.10.7->replicate) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>1.10.7->replicate) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain_community<0.3.0) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain_community<0.3.0) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community<0.3.0) (3.4.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.33->langchain_core->ibm-granite-community-utils==0.1.dev154) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community<0.3.0) (1.1.0)

# %%
import os
import replicate
from langchain_community.llms import Replicate
from ibm_granite_community.notebook_utils import get_env_var
import ipywidgets as widgets
from IPython.display import display, Markdown, HTML
from string import Template

# %%
#Use the utility function to get from environment or prompt
replicate_api_token = get_env_var("REPLICATE_API_TOKEN")
os.environ["REPLICATE_API_TOKEN"] = replicate_api_token
# Out:
# REPLICATE_API_TOKEN loaded from Google Colab secret.

# %%
# Model configuration - matching reference implementation
MODEL_NAME = "ibm-granite/granite-3.3-8b-instruct"
MAX_TOKENS = 1024
TEMPERATURE = 0.2

# Initialize the model
llm = Replicate(
    model=MODEL_NAME,
    model_kwargs={
        "max_tokens": MAX_TOKENS,
        "temperature": TEMPERATURE
    }
)

print(f"✅ Model initialized: {MODEL_NAME}")
print(f"   Max Tokens: {MAX_TOKENS}")
print(f"   Temperature: {TEMPERATURE}")
# Out:
# ✅ Model initialized: ibm-granite/granite-3.3-8b-instruct
#    Max Tokens: 1024
#    Temperature: 0.2

# %%
# Task 3: Draft an initial prompt for a specific project
# This is NOT a template yet - it's hard-coded for one specific use case

baseline_prompt = """Write a concise weekly status summary for the
DeltaFin
client project.
Highlight progress made this week, note any blockers, and outline next
steps in a
professional
tone suitable for a client email."""

print("TASK 3: Baseline Prompt (Single-Use)")
print("-" * 70)
print("\nPrompt:")
print(baseline_prompt)
print("\n" + "-" * 70)
print("Generating output...")

# Generate output using the baseline prompt
baseline_output = llm.invoke(baseline_prompt)

print("Generated Output:")
print("-" * 70)
print(baseline_output)
print("-" * 70)
# Out:
# TASK 3: Baseline Prompt (Single-Use)
# ----------------------------------------------------------------------
#
# Prompt:
# Write a concise weekly status summary for the
# DeltaFin
# client project.
# Highlight progress made this week, note any blockers, and outline next
# steps in a
# professional
# tone suitable for a client email.
#
# ----------------------------------------------------------------------
# Generating output...
# Generated Output:
# ----------------------------------------------------------------------
# Subject: DeltaFin Project Weekly Status Update
#
# Dear [Client's Name],
#
# I hope this message finds you well. I am writing to provide an update on our ongoing DeltaFin project.
#
# This week, our team has made significant strides in the following areas:
#
# 1. **Data Migration**: We successfully migrated 80% of the target data sets to the new system, with minimal data discrepancies identified and rectified.
#
# 2. **System Integration**: The integration of the new payment gateway has been completed and tested, ensuring seamless transaction processing.
#
# 3. **User Acceptance Testing (UAT)**: We initiated the UAT phase for the revamped user interface, receiving positive feedback from the initial group of testers.
#
# However, we have encountered a few blockers that require your attention:
#
# 1. **Regulatory Compliance**: The legal team has raised concerns regarding certain data handling procedures. We are awaiting their final approval before proceeding with the full-scale data migration.
#
# 2. **Third-Party Vendor**: We are still awaiting the delivery of the customized hardware from our vendor, which is crucial for the project's final stages.
#
# Looking ahead, our next steps are as follows:
#
# 1. **Regulatory Approval**: We will liaise with the legal team to address their concerns and secure the necessary approvals.
#
# 2. **Vendor Delivery**: We will maintain regular communication with the vendor to expedite the delivery of the hardware.
#
# 3. **UAT Expansion**: Once the above blockers are resolved, we will expand the UAT phase to gather comprehensive user feedback.
#
# We appreciate your patience and understanding as we navigate these challenges. Rest assured, our team is working diligently to ensure the project's timely completion while maintaining the highest quality standards.
#
# Should you have any questions or require further clarification, please do not hesitate to reach out.
#
# Best Regards,
#
# [Your Name]
# [Your Position]
# [Your Contact Information]
# ----------------------------------------------------------------------

# %%
# Task 4: Convert the baseline prompt into a reusable template with variables

# Using Python’s string formatting with named placeholders
prompt_template = """Write a concise weekly status summary for the
{client_name} project.

Summarize progress made during {time_period}, note {blockers}, and outline
{next_steps}
in a {tone} tone suitable for {audience}.

Additional context:
- progress: {progress}
- format: {output_format}"""

print("TASK 4: Reusable Prompt Template")
print("-" * 70)
print("\nTemplate with Variables:")
print("-" * 70)
print(prompt_template)
print("-" * 70)


print("\n Template created successfully!")
print("\nVariables identified:")
variables = ["{client_name}", "{time_period}", "{progress}",
"{blockers}",
 "{next_steps}", "{tone}", "{audience}",
"{output_format}"]
for var in variables:
 print(f" – {var}")
# Out:
# TASK 4: Reusable Prompt Template
# ----------------------------------------------------------------------
#
# Template with Variables:
# ----------------------------------------------------------------------
# Write a concise weekly status summary for the
# {client_name} project.
#
# Summarize progress made during {time_period}, note {blockers}, and outline
# {next_steps}
# in a {tone} tone suitable for {audience}.
#
# Additional context:
# - progress: {progress}
# - format: {output_format}
# ----------------------------------------------------------------------
#
#  Template created successfully!
#
# Variables identified:
#  – {client_name}
#  – {time_period}
#  – {progress}
#  – {blockers}
#  – {next_steps}
#  – {tone}
#  – {audience}
#  – {output_format}

# %% [markdown]
# ##Test Case 1: DeltaFin Project (Financial Services)

# %%
# Test Case 1: DeltaFin Project (Financial Services)
# Define variables for Project 1: DeltaFin
project1_vars = {
 "client_name": "DeltaFin",
 "time_period": "Week 4",
 "progress": "Completed API integration testing and resolved 15 critical bugs",
 "blockers": "Testing delays caused by the external vendor's infrastructure issues",
 "next_steps": "Finalize the integration plan and begin UAT preparation",
 "tone": "formal",
 "audience": "senior client stakeholders",
 "output_format": "structured paragraph with clear sections"
}

# Substitute variables into the template
project1_prompt = prompt_template.format(**project1_vars)

print("TASK 5: Testing Template - Project 1 (DeltaFin)")
print("-" * 70)
print("\nVariable Values:")
for key, value in project1_vars.items():
 print(f"{key}: {value}")

print("\n" + "-" * 70)
print("\nGenerated Prompt:")
print("-" * 70)
print(project1_prompt)
print("-" * 70)

print("\n" + "-" * 70)
print("Generating output... \n")

# Generate output
project1_output = llm.invoke(project1_prompt)

print("Generated Status Summary:")
print("-" * 70)
print(project1_output)
print("-" * 70)
# Out:
# TASK 5: Testing Template - Project 1 (DeltaFin)
# ----------------------------------------------------------------------
#
# Variable Values:
# client_name: DeltaFin
# time_period: Week 4
# progress: Completed API integration testing and resolved 15 critical bugs
# blockers: Testing delays caused by the external vendor's infrastructure issues
# next_steps: Finalize the integration plan and begin UAT preparation
# tone: formal
# audience: senior client stakeholders
# output_format: structured paragraph with clear sections
#
# ----------------------------------------------------------------------
#
# Generated Prompt:
# ----------------------------------------------------------------------
# Write a concise weekly status summary for the
# DeltaFin project.
#
# Summarize progress made during Week 4, note Testing delays caused by the external vendor's infrastructure issues, and outline
# Finalize the integration plan and begin UAT preparation
# in a formal tone suitable for senior client stakeholders.
#
# Additional context:
# - progress: Completed API integration testing and resolved 15 critical bugs
# - format: structured paragraph with clear sections
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Generating output...
#
# Generated Status Summary:
# ----------------------------------------------------------------------
# **DeltaFin Project Weekly Status Summary - Week 4**
#
# **Progress Overview:**
#
# This week marked significant advancements in the DeltaFin project, with the completion of API integration testing and the resolution of 15 critical bugs. These achievements have laid a robust foundation for the subsequent phases of the project.
#
# **Challenges Encountered:**
#
# Notably, the project encountered unforeseen delays due to infrastructure issues experienced by our external vendor. These challenges have temporarily impeded the testing phase, necessitating a recalibration of our timeline to accommodate the vendor's resolution efforts.
#
# **Upcoming Actions:**
#
# In light of the current situation, our focus shifts to finalizing the integration plan. This involves meticulous review and documentation of all integrated components to ensure seamless operation. Concurrently, we are initiating the preparatory stages for User Acceptance Testing (UAT), which will involve close collaboration with key stakeholders to align on acceptance criteria and testing scenarios.
#
# We remain committed to transparent communication and are actively monitoring the vendor's progress to expedite the resolution of the infrastructure issues. Our team is prepared to adapt and mitigate any further impact on the project timeline.
#
# **Next Steps:**
#
# 1. Finalize the integration plan by [Date].
# 2. Commence UAT preparation by [Date].
# 3. Continue liaising with the vendor for timely infrastructure resolution.
#
# We appreciate your understanding and support as we navigate these temporary setbacks. Our dedication to delivering a high-quality DeltaFin solution remains unwavering.
#
# **Prepared by:**
# [Your Name]
# [Your Position]
# [Date]
# ----------------------------------------------------------------------

# %% [markdown]
# ### Test Case 2: MediTrack Project (Healthcare Technology)

# %%
# Test Case 2: MediTrack Project (Healthcare Technology)
# Define variables for Project 2: MediTrack
project2_vars = {
 "client_name": "MediTrack",
 "time_period": "Sprint 2",
 "progress": "Successfully deployed the patient data dashboard and completed security audit",
 "blockers": "pending approvals from the compliance team for HIPAA certification",
 "next_steps": "complete the data-mapping activity and prepare for pilot testing",
 "tone": "neutral, business-professional",
 "audience": "internal project sponsors",
 "output_format": "bullet-point list with clear categories"
}

# Substitute variables into the template
project2_prompt = prompt_template.format(**project2_vars)

print("TASK 5: Testing Template - Project 2 (MediTrack)")
print("-" * 70)
print("\nVariable Values:")
for key, value in project2_vars.items():
 print(f"{key}: {value}")

print("\n" + "-" * 70)
print("\nGenerated Prompt:")
print("-" * 70)
print(project2_prompt)
print("-" * 70)

print("\n" + "-" * 70)
print("Generating output... \n")

# Generate output
project2_output = llm.invoke(project2_prompt)

print("Generated Status Summary:")
print("-" * 70)
print(project2_output)
print("-" * 70)
# Out:
# TASK 5: Testing Template - Project 2 (MediTrack)
# ----------------------------------------------------------------------
#
# Variable Values:
# client_name: MediTrack
# time_period: Sprint 2
# progress: Successfully deployed the patient data dashboard and completed security audit
# blockers: pending approvals from the compliance team for HIPAA certification
# next_steps: complete the data-mapping activity and prepare for pilot testing
# tone: neutral, business-professional
# audience: internal project sponsors
# output_format: bullet-point list with clear categories
#
# ----------------------------------------------------------------------
#
# Generated Prompt:
# ----------------------------------------------------------------------
# Write a concise weekly status summary for the
# MediTrack project.
#
# Summarize progress made during Sprint 2, note pending approvals from the compliance team for HIPAA certification, and outline
# complete the data-mapping activity and prepare for pilot testing
# in a neutral, business-professional tone suitable for internal project sponsors.
#
# Additional context:
# - progress: Successfully deployed the patient data dashboard and completed security audit
# - format: bullet-point list with clear categories
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Generating output...
#
# Generated Status Summary:
# ----------------------------------------------------------------------
# - **Sprint 2 Progress:**
#   - Successfully deployed the patient data dashboard, enhancing user accessibility to critical patient information.
#   - Completed a comprehensive security audit, ensuring robust data protection measures are in place.
#
# - **Pending Approvals:**
#   - Currently awaiting HIPAA certification approval from the compliance team, crucial for maintaining regulatory compliance.
#
# - **Upcoming Activities:**
#   - Complete the data-mapping activity to ensure seamless integration of various data sources within the MediTrack system.
#   - Prepare for pilot testing, aiming to validate system functionality and gather user feedback for refinement.
#
# - **Next Steps:**
#   - Coordinate closely with the compliance team to expedite HIPAA certification.
#   - Finalize data-mapping to support pilot testing readiness.
#   - Schedule pilot testing with key stakeholders to assess system performance and user experience.
#
# This summary reflects the project's advancements and outlines the critical steps necessary to progress towards the pilot testing phase, emphasizing the importance of timely HIPAA compliance approval.
# ----------------------------------------------------------------------

# %% [markdown]
# ### Task 5: Conclusion
#
# **Testing Results:**
# - ✅ Template produces consistent, high-quality outputs
# - ✅ Successfully adapts to different contexts
# - ✅ Maintains appropriate tone for each audience
# - ✅ Generates properly formatted summaries
#
# **Template Benefits:**
# 1. **Time Savings**: Analysts don't rewrite prompts from scratch
# 2. **Consistency**: All outputs follow the same structure
# 3. **Quality**: Professional standards maintained across team
# 4. **Scalability**: Works for unlimited number of projects
# 5. **Flexibility**: Adapts to different tones and audiences
#
# **Conclusion:** Your template now produces clear, consistent outputs for any project in your team. You've successfully created a scalable, reusable prompt template that analysts across the organization can use.
